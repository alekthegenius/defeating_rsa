# %%
import math
import random

# %%
def random_prime(mn=2, mx=100):
    prime_flag = 0
    while prime_flag == 0:
        rand = random.randint(mn, mx)
        for i in range(2, int(math.sqrt(rand)) + 1):
            print(i)
            if (rand % i == 0):
                prime_flag = 1
                break
    return rand

d= random_prime(1000000000000000000, 9000000000000000000)
print(d)
# Out:
# 2
# 8100059670558328016

# %%
23%7
# Out:
# 2

# %%
9223372036854775808*10**-18
# Out:
# 9.223372036854776

# %%
len(str(2**63))
# Out:
# 19

# %%
n = ...
print(n)
len(str(n))
# Out:
# ...
# 617

# %%
2**2048
# Out:
# ...

# %%
math.sqrt()
# Out:
# 9.344346388415145e+153

# %%
len(bin(2**2048)[2:])
# Out:
# 2049

# %%
2**16+1
# Out:
# 65537

# %%
math.log2(2**2048+1)
# Out:
# 2048.0

# %%
(1%51600)
# Out:
# 1

# %%
5**4
# Out:
# 625

# %%
(1/34992)% ...
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 (1/34992)% [38;5;241;...
#
# OverflowError: int too large to convert to float
